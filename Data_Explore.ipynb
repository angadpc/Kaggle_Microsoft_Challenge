# %%
import numpy as np
import pandas as pd
import random

# %%
df_chunk = pd.read_csv('/Users/angadchandratre/Downloads/documents/train.csv', chunksize=500000)

# %% [markdown]
# **EXPLORE RANDOM SAMPLE OF DATA**

# %%
filename = '/Users/angadchandratre/Downloads/documents/train.csv'
n = sum(1 for line in open(filename))-1  # Calculate number of rows in file
s = n//10  # sample size of 10%
skip = sorted(random.sample(range(1, n+1), n-s))  # n+1 to compensate for header 
df = pd.read_csv(filename, skiprows=skip)
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
total_num_rows = n
total_num_rows
# Out:
# 8921483

# %%
#Shape of sample data 
df.shape
# Out:
# (892148, 83)

# %%
df.head(10)
# Out:
#                   MachineIdentifier   ProductName EngineVersion  \
# 0  000007905a28d863f6d0d597892cd692  win8defender   1.1.15100.1
# 1  00000b11598a75ea8ba1beea8459149f  win8defender   1.1.15100.1
# 2  0000258d2b847c7549150cfec6464473  win8defender   1.1.15100.1
# 3  000038f24a1ee98931456b3e49f7934b  win8defender   1.1.15200.1
# 4  000043b6d35721598e8bc43f8c354124  win8defender   1.1.13504.0
# 5  0000665576f3439c9c1db30d878a821e  win8defender   1.1.15200.1
# 6  00006f65a3ed72af6a8b3e4005044e90  win8defender   1.1.14104.0
# 7  0000a8f6da8be7c59a5ce7603406bfd0  win8defender   1.1.15100.1
# 8  0000b73b09940321a18f4d3ea53555a2  win8defender   1.1.15100.1
# 9  0000ba348123780f135d51d721348be3  win8defender   1.1.15200.1
#
#         AppVersion  AvSigVersion  IsBeta  RtpStateBitfield  IsSxsPassiveMode  \
# 0  4.18.1807.18075  1.273.1341.0       0               7.0                 0
# 1  4.18.1807.18075  1.273.1527.0       0               7.0                 0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892148 entries, 0 to 892147
# Data columns (total 83 columns):
# MachineIdentifier                                    892148 non-null object
# ProductName                                          892148 non-null object
# EngineVersion                                        892148 non-null object
# AppVersion                                           892148 non-null object
# AvSigVersion                                         892148 non-null object
# IsBeta                                               892148 non-null int64
# RtpStateBitfield                                     888939 non-null float64
# IsSxsPassiveMode                                     892148 non-null int64
# DefaultBrowsersIdentifier                            43182 non-null float64
# AVProductStatesIdentifier                            888583 non-null float64
# AVProductsInstalled                                  888583 non-null float64
# ...

# %% [markdown]
# **PREPROCESS DATA CHUNK BY CHUNK**

# %%
chunk_list = []

# %%
#add any additional preprocessing steps. 
def chunk_preprocessing(chunk):

# %%
for chunk in df_chunk:
    chunk_filter = chunk_preprocessing(chunk)
    chunk_list.append(chunk_filter)

# %%
df_concat = pd.concat(chunk_list)
